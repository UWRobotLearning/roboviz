# %%
from roboviz.app.segmentation import extract_one_demos, extract_states, extract_states_trajectory_separated

# %%
dataset_path = "/Users/hendramarco/Documents/roboviz/expert_demos.hdf5"  # path to dataset, to be changed by user
trajectory_separated = extract_states_trajectory_separated(dataset_path)
states = extract_states(dataset_path)
one_demo = extract_one_demos(dataset_path)
min_cluster_size = int(0.1 * states.shape[0])
# Out:
# Num demos loaded: 1

# %%
from roboviz.app.segmentation import hdbscan, hdbscan_predict, calculate_eps, split_edges

# %%
states.shape
# Out:
# (110, 8)
